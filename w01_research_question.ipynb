# %% [markdown]
# <a href="https://colab.research.google.com/github/SHIVATHMIKA26/flyrank-ml-internship/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SHIVATHMIKA26/FLYRANKa1/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose the **Content Refresh Prediction** lane because it focuses on identifying web pages that are likely to decline in performance and should be refreshed. This is a practical SEO problem where machine learning can help prioritize pages that need attention. Instead of manually reviewing thousands of pages, a predictive model can assist teams in making faster and more informed decisions.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### Decision
# Which web pages should be prioritized for content refresh?
#
# ### Action
# The SEO or content team reviews and updates the pages predicted to decline in performance.
#
# ### Cost of a Wrong Recommendation
# If a declining page is not identified, it may continue losing organic traffic and visibility. If a healthy page is incorrectly recommended for refresh, time and resources may be spent on unnecessary updates.
#
# ### Why Machine Learning?
# Many factors, such as impressions, click-through rate (CTR), content age, and average search position, influence page performance. Machine learning can analyze these factors together and provide decision support that is more effective than relying on a single manual rule.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))

print("\nTrend Direction Counts:")
print(df["trend_direction"].value_counts())

print("\nAverage CTR:", round(df["ctr"].mean(), 4))
print("Average Content Age (days):", round(df["content_age_days"].mean(), 2))
# Out:
# Rows: 30000
# Columns: 44
#
# Trend Direction Counts:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Average CTR: 0.5107
# Average Content Age (days): 256.17

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project provides **decision support** by identifying patterns observed in the anonymized dataset. The results can help prioritize web pages for content refresh based on measured factors such as impressions, click-through rate, content age, and average position.
#
# The findings are **observed** and **directional**, not proof of cause and effect. This project does **not** predict Google's search algorithm or guarantee future rankings. Any recommendations produced by the model should be used to support human decision-making and should be validated before taking action.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
